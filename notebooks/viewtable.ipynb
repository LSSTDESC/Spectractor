# %% [markdown]
# # Dump Spectractor Tables

# %%
import pandas as pd
# %matplotlib inline

# %%
#file="/Users/dagoret/DATA/PicDuMidiFev2019/spectractor_output_deco/20190215/T1M_20190216_050239_104_HD116405_Filtre_None_bin1x1.439_red_table.csv"
#file="/Users/dagoret/DATA/PicDuMidiFev2019/spectractor_output_prod3/20190215/T1M_20190216_013737_612_HD116405_Filtre_None_bin1x1.121_red_table.csv"
file="../output_test/20190215/T1M_20190216_050314_384_HD116405_Filtre_None_bin1x1.440_red_table.csv"
#T1M_20190216_050314_384_HD116405_Filtre_None_bin1x1.440_red_spectrum.fits

# %%
ls -t -l ../output_test/20190215/
# Out:
# total 66312
# -rw-r--r--  1 dagoret  LAL\Utilisateurs du domaine    575314 Jun 13 15:18 T1M_20190216_050314_384_HD116405_Filtre_None_bin1x1.440_red_table.csv
# -rw-r--r--  1 dagoret  LAL\Utilisateurs du domaine  33321600 Jun 13 15:18 T1M_20190216_050314_384_HD116405_Filtre_None_bin1x1.440_red_spectrogram.fits
# -rw-r--r--  1 dagoret  LAL\Utilisateurs du domaine     48960 Jun 13 15:18 T1M_20190216_050314_384_HD116405_Filtre_None_bin1x1.440_red_spectrum.fits

# %%
df=pd.read_csv(file)

# %%
df
# Out:
#           lambdas           Dx           Dy      Dy_mean    flux_sum  \
# 0      298.994785   479.594675   476.886833   473.632847  -34.558945
# 1      299.404798   480.306191   477.588376   474.335518  -40.798071
# 2      299.847448   481.017706   478.289922   475.038188  -38.226675
# 3      300.290095   481.729222   478.991470   475.740859  -44.432921
# 4      300.732738   482.440737   479.693020   476.443529  -37.301870
# 5      301.175377   483.152252   480.394573   477.146200  -42.746403
# 6      301.618012   483.863768   481.096127   477.848870  -38.564307
# 7      302.060643   484.575283   481.797684   478.551541  -49.688358
# 8      302.503270   485.286798   482.499244   479.254212  -34.413469
# 9      302.945893   485.998314   483.200805   479.956882  -39.483171
# 10     303.388513   486.709829   483.902369   480.659553  -38.172877
# 11     303.831128   487.421345   484.603935   481.362223  -34.005441
# 12     304.273739   488.132860   485.305503   482.064894  -37.762026
# ...

# %%
chi2=df["chi2_red"]

# %%
ax=chi2.plot(figsize=(10,5))
ax.set_title("chi2/Ndof")
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
ax=chi2.hist(bins=50,figsize=(10,6))
ax.set_title("chi2/Ndof")
ax.set_xlabel("")
# Out:
# Text(0.5, 0, '')
